# %% [markdown]
# ## Question 1
#
# Install Python and understand the difference between scripting mode and interactive mode in IDLE.

# %%
import sys

print("Python is installed.")
print("Version:", sys.version)


# Interactive mode executes one statement at a time and shows the result immediately.
# Scripting mode means writing a complete Python program in a file with the
# .py extension and then running the whole file.
# Out:
# Python is installed.
# Version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Question 2
#
# Write Python programs to print strings in the given manner.

# %%
# 2(a)
# print("Hello Everyone !!!")
print("Hello sir have a good day greeting by Ravi")

# 2(b)
# print("Hello")
# print("World")
print("hello")
print("Sir")

# 2(c)
# print("Hello\nWorld")
print("Hello\nSir")

# 2(d)
# print("Rohit's date of birth is 12\05\1999")
print("My DOB is 30th of april 2002")


# print() is a built-in Python function used to display output on the screen.
# The text inside quotes (" ") is called a string.
# When Python runs the print() functionit displays the string on the screen.
# Out:
# Hello sir have a good day greeting by Ravi
# hello
# Sir
# Hello
# Sir
# My DOB is 30th of april 2002

# %% [markdown]
# ## Question 3
#
# Declare a string variable called `x` and assign it the value `Hello`. Print the value of `x`.

# %%
x="Hello"
print(x)

# Python creates a variable named x.
# It stores the string "Hello" in that variable.
# Python looks at the variable x.
# It finds that x contains "Hello".
# It displays Hello on the screen.
# A variable is a named storage location used to store data.
# Python stores the value in the variable
# and whenever you use the variable name, Python retrieves and uses the stored value.
# Out:
# Hello

# %% [markdown]
# ## Question 4
#
# Take different data types and print values using the `print()` function.

# %%
integer=58
decimal=21.22
text="text value"
boolean=True
lst=["a","b","c"]

print(integer,decimal,text,boolean,lst,sep="\n")

# Here simply different values are assign to different variables and then simply printed
# Out:
# 58
# 21.22
# text value
# True
# ['a', 'b', 'c']

# %% [markdown]
# ## Question 5
#
# Take two variables `a` and `b`. Assign your first name and last name. Print your full name by adding both.

# %%
a="Ravinder"
b="Singh"
print(a+b)

# Here simply we used two variable and then assign value using (=) and then printed 
# it using + here + is an example of operator overloading 
# operator overloading simply means when one operator can perform different operation
# based on the data type used simple
# Out:
# RavinderSingh

# %% [markdown]
# ## Question 6
#
# Declare first name, last name, and nickname. Print as: `FirstName (Nickname) LastName`.

# %%
first_name=a
last_name=b
nickname="(Ravi)"
print(first_name,nickname,last_name,sep=" ")

# we already got the first and last name in previous question we simply assign them to new variables
# and then simply print it we use the argument sep.
# sep means separator it means if we are printing various value what we want between them
# example a space dot anything we can do that using sep argument
# Out:
# Ravinder (Ravi) Singh

# %% [markdown]
# ## Question 7
#
# Declare and assign suitable variables, then print the details in the required format.

# %%
sap="590030651"
dob="30th April 2002"
add="UPES"
program="MCA"
sem="1"

print(f" Hi my name is {a} {b} and my date of birth is {dob}.\n I am pursuing {program} from {add} and this is my semester {sem} ")

# here ive used formated string also known as f string you can simply use variables aand 
# expression using {} braces using it is simple you just have to typr f then "" and you can 
# write anything between thoose semicolons if you want variable use {}.
# this makes your code easy to write or else you have to write text in double qoute then a
# variable then again print for changing line so its more suitable

print()
print("Hi my name is", a, b, "and my date of birth is", dob)
print("I am pursuing", program, "from", add, "and this is my semester", sem)

#Thats how you write it without the f string too much of task.
# Out:
#  Hi my name is Ravinder Singh and my date of birth is 30th April 2002.
#  I am pursuing MCA from UPES and this is my semester 1
#
# Hi my name is Ravinder Singh and my date of birth is 30th April 2002
# I am pursuing MCA from UPES and this is my semester 1

# %%
# As i suggest that a concise code is easier to read, maintain, debug, and reduces code repetition. 
# The goal is to improve code readability, not just to reduce the number of lines.
